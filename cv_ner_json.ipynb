# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/iamrajee/Data-Analysis/blob/master/cv_ner_json.ipynb)

# %%
# !ls
# Out:
# 1.json	2.json	3.json	4.json	datalab  drive	nltk_data

# %%
import numpy as np

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# !pip install spacy
# !pip install nltk
# !python3 -m spacy download en
import spacy
import nltk
import numpy as np
nltk.download('all')
en_nlp = spacy.load('en')
from nltk import Tree
# Out:
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')
#
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /content/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /content/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# ...

# %%
import json
from pprint import pprint





# f = open("1.json","r")
# data = f.read()
# print(data)

# print(np.shape(data))
# print(type(data))
# print(len(data))
# print(data[8])
# type(data)

# %%
datastore = []
l = 4
path1 = "drive/ML/cv/json2"
for i in range(1,l+1):
  filename = path1 + "/"+str(i)+".json"
  with open(filename, 'r') as f:
      tempdatastore = json.load(f)
  datastore.append(tempdatastore)

# %%
print(type(datastore), type(datastore[0]), datastore[0])
print(len(datastore[0]))
print(datastore[0]['Date of birth'][0]['text'])
# Out:
# <class 'list'> <class 'dict'> {'Date of birth': [{'text': '17 February 1979 ', 'direction': 'ltr', 'width': 74.64, 'height': 8, 'top': 768.68, 'left': 142, 'transform': [8, 0, 0, 8, 142, 768.68], 'fontSize': 8, 'fontName': 'g_d0_f2', 'fontOriginName': 'LQEXLG+Verdana', 'bold': False, 'italic': False, 'black': False, 'color': '[0,0,0]'}], 'Nationality ': [{'text': 'Italian ', 'direction': 'ltr', 'width': 28.360000000000003, 'height': 8, 'top': 753.68, 'left': 142, 'transform': [8, 0, 0, 8, 142, 753.68], 'fontSize': 8, 'fontName': 'g_d0_f2', 'fontOriginName': 'LQEXLG+Verdana', 'bold': False, 'italic': False, 'black': False, 'color': '[0,0,0]'}], 'Contact details': [{'text': 'Email: ', 'direction': 'ltr', 'width': 28.456000000000003, 'height': 8, 'top': 738.68, 'left': 142, 'transform': [8, 0, 0, 8, 142, 738.68], 'fontSize': 8, 'fontName': 'g_d0_f2', 'fontOriginName': 'LQEXLG+Verdana', 'bold': False, 'italic': False, 'black': False, 'color': '[0,0,0]'}, {'text': 'maurizio.lettieri@alumn
# ...

# %%
print(datastore[0].keys())
# Out:
# dict_keys(['Date of birth', 'Nationality ', 'Contact details', 'Permanent address', ' ', 'SUMMARY', 'PROFESSIONAL EXPERIENCE', 'EDUCATION', 'LANGUAGES', 'OTHER EXPERIENCE', 'AWARDS', 'PERSONAL INTERESTS'])

# %%
# dictlabelist = list(datastore[0].keys())
# print(type(dictlabelist), dictlabelist)

# %%
datastore[3].keys()
# Out:
# dict_keys(['Nationality ', 'Contact details', 'Permanent address', 'OBJECTIVE', ' ', 'PROFESSIONAL EXPERIENCE', 'EDUCATION', 'LANGUAGES', 'OTHER EXPERIENCE', 'PERSONAL INTERESTS'])

# %%
# print(datastore[0][])

# %%
for i,docdict in enumerate(datastore):
  print("\n\n\n-------------------( "+str(i)+" )------------------")
  tempdictlabelist = list(docdict.keys())
#   print(i,datastore[i].keys())
#   print(i,datastore[i][dictlabelist[0]][0]['text'])
  for templabel in tempdictlabelist:
    if templabel !=' ':
      print(templabel, end="-------> ")
      for j in range(0,len(docdict[templabel])):
        print(j,docdict[templabel][j]['text'])
# Out:
# -------------------( 0 )------------------
# Date of birth-------> 0 17 February 1979
# Nationality -------> 0 Italian
# Contact details-------> 0 Email:
# 1 maurizio.lettieri@alumni.insead.edu
# 2
# 3 Tel: +33687279684 (until July07) Mobile: +393488889498
# Permanent address-------> 0 Viale Gallerani 6 21047 Saronno VA Italy
# SUMMARY-------> 0 Seeking a position in a dynamic and team oriented environment whereby I will be assessed against
# 1 challenging objectives
# 2
# PROFESSIONAL EXPERIENCE-------> 0 2004 - 2006
# 1 McKinsey and Company
# 2 Italy
# 3 Management Consulting
# 4 Business Analyst
# 5 Strategic Marketing
# 6 •
# 7 Defined long-term marketing strategy for a leading telecommunication company
# 8 •
# 9 Developed a business plan for three main segments and assessed opportunities for incumbent
# 10 and new entrants (virtual operator, segment focus approach)
# 11 Sales
# 12 •
# ...

# %%
from spacy import displacy

text = """But Google is starting from behind. The company made a late push
into hardware, and Apple’s Siri, available on iPhones, and Amazon’s Alexa
software, which runs on its Echo and Dot devices, have clear leads in
consumer adoption."""

# nlp = spacy.load('custom_ner_model')
doc = en_nlp(text)
displacy.render(doc, style='ent', jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is starting from behind. The company made a late push
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# into hardware, and
# ...

# %%
def tok_format(tok):
    return "_".join([tok.orth_, tok.tag_])


def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(tok_format(node), [to_nltk_tree(child) for child in node.children])
    else:
        return tok_format(node)

# %%
doc = en_nlp(u"bright red apples on the tree")
# doc1 = "Dependency parsing with ID/LP rules is trivial if you have a lexicon. One uses a (declarative) generate-and-test approach. Dependency trees are rooted spanning trees on a graph with n nodes where n is the length of the processed sentence. One can declare what a tree is and - now comes the linguistic part - where an edge (that is, a dependency) may be. The result are all spanning trees composed of the possible dependencies. Thus dependency parsing is constraint solving."
# doc = en_nlp(doc1)
# # doc = en_nlp(u"Autonomous cars shift insurance liability toward manufacturers")
[to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
print([token.text for token in doc[2].lefts])  # ['bright', 'red']
print([token.text for token in doc[2].rights])  # ['on']
print(doc[2].n_lefts)  # 2
print(doc[2].n_rights)  # 1
# Out:
#           apples_NNS
#      _________|_________
#     |         |       on_IN
#     |         |         |
#     |         |      tree_NN
#     |         |         |
# bright_JJ   red_JJ    the_DT
#
# ['bright', 'red']
# ['on']
# 2
# 1

# %%
for i,docdict in enumerate(datastore):
  if i == 0:
    print("\n\n\n-------------------( "+str(i)+" )------------------")
    tempdictlabelist = list(docdict.keys())
    for templabel in tempdictlabelist:
      if templabel !=' ':
        print(templabel, end="-------> ")
        for j in range(0,len(docdict[templabel])):
          print(j,docdict[templabel][j]['text'])
          
          tempsent = docdict[templabel][j]['text']
          tempsent = en_nlp(str(tempsent))
          [to_nltk_tree(sent.root).pretty_print() for sent in tempsent.sents]
# Out:
# -------------------( 0 )------------------
# Date of birth-------> 0 17 February 1979
#       February_NNP
#    ________|__________
# 17_CD              1979_CD
#
# Nationality -------> 0 Italian
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-5a4fdb82500a> in <module>()
#      11           tempsent = docdict[templabel][j]['text']
#      12           tempsent = en_nlp(str(tempsent))
# ---> 13           [to_nltk_tree(sent.root).pretty_print() for sent in tempsent.sents]
#
# <ipython-input-45-5a4fdb82500a> in <listcomp>(.0)
#      11           tempsent = docdict[templabel][j]['text']
#      12           tempsent = en_nlp(str(tempsent))
# ---> 13           [to_nltk_tree(sent.root).pretty_print() for sent in tempsent.sents]
#
# AttributeError: 'str' object has no attribute 'pretty_print'

# %%
# doc = 
# [to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
# Out:
#           apples_NNS
#      _________|_________
#     |         |       on_IN
#     |         |         |
#     |         |      tree_NN
#     |         |         |
# bright_JJ   red_JJ    the_DT
# [None]
