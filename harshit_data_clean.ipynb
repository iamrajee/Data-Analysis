# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/iamrajee/Data-Analysis/blob/master/harshit_data_clean.ipynb)

# %%
# !ls
# Out:
# datalab  Jazz_Disc3_SJJune2018.xls  lastfinallist (1).csv  lastfinallist.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8cde28a-51a7-41fe-b770-47c5a3b87ffb" name="files[]" multiple disabled />
#      <output id="result-a8cde28a-51a7-41fe-b770-47c5a3b87ffb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Jazz_Disc3_SJJune2018.xls to Jazz_Disc3_SJJune2018.xls

# %%
# %%time
# !pip install spacy
# !python3 -m spacy download en
import spacy
en_nlp = spacy.load('en')
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/3c/31/e60f88751e48851b002f78a35221d12300783d5a43d4ef12fbf10cca96c3/spacy-2.0.11.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/5e/31/c8c1ecafa44db30579c8c457ac7a0f819e8b1dbc3e58308394fff5ff9ba7/murmurhash-0.28.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/9e/273fbea507de99166c11cd0cb3fde1ac01b5bc724d9a407a2f927ede91a1/cymem-1.31.2.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/1b/ac/7c17b1fd54b60972785b646d37da2826311cca70842c011c4ff84fbe95e0/preshed-1.0.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/55/fd/e9f36081e6f53699943381858848f3b4d759e0dd03c43b98807dde34c252/thinc-6.10.2.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/9e/9b/62c60d2f5bc135d2aa1d8c8a86aaf84edb719a59c7f11a4316259e61a298/plac-0.9.6-py2.py3-none-any.whl
# ...

# %%
# !pip install xlrd

# %%
import pandas as pd
import xlrd
import numpy as np

# %%
# %%time
xls = pd.ExcelFile('Jazz_Disc3_SJJune2018.xls')
df_ = []
df_.append(pd.read_excel(xls, 'albums'))
df_.append(pd.read_excel(xls, 'albums 1'))
df_.append(pd.read_excel(xls, 'albums 2'))
df_.append(pd.read_excel(xls, 'albums 3'))

values = []
values.append(df_[0]['location'].values)
values.append(df_[1]['location'].values)
values.append(df_[2]['location'].values)
values.append(df_[3]['location'].values)

for i in range(0,4):
  print(np.shape(values[i]))
  
valuesall = []
for i in range(0,4):
  for rowlist in values[i]:
    valuesall.append(rowlist)
    
print(len(valuesall))
# Out:
# (50000,)
# (50000,)
# (50000,)
# (3961,)
# 153961
# CPU times: user 27.6 s, sys: 287 ms, total: 27.9 s
# Wall time: 27.9 s

# %%
df2 = pd.read_csv('world_cities.csv')
print(df2.columns)
subcoulist = df2['subcountry']
coulist = df2['country']
namelist = df2['name']


# subcoulist = np.unique(subcoulist)
coulist = np.unique(coulist)
namelist = np.unique(namelist)
                    
print(len(subcoulist))
print(len(coulist))
print(len(namelist))
# Out:
# Index(['name', 'country', 'subcountry', 'geonameid'], dtype='object')
# 23020
# 245
# 21942

# %%
df = pd.read_excel('jazz_albums.xlsx')

# %%
print(df.columns)
# Out:
# Index(['lid', 'rid', 'year', 'month', 'day', 'location', 'title',
#        'carryForward', 'printDate', 'notes', 'session', 'city'],
#       dtype='object')

# %%
citylist = df['city']
len(citylist)
# Out:
# 153961

# %%
# citylist = citylist[0:100]
# print(citylist)

# %%
splitcitylist = []
for z,row in enumerate(citylist):
  splitcitylist.append(str(row).split('|'))

# %%
print(len(splitcitylist))
# Out:
# 153961

# %%
# %%time
#initially removing substring
newlist = []
for z,rowlist in enumerate(splitcitylist):
  templist = []
  for i,string1 in enumerate(rowlist):
    string1 = string1.strip()
    flag1 = 0
    flag2 = 0
    for j,string2 in enumerate(rowlist):
      if string1 in string2 and i != j:
        flag1 = 1
    if flag1 == 0:
      templist.append(string1)
  newlist.append(templist)
#   if z in range(115,120):
#     print(z,templist,rowlist)
# Out:
# CPU times: user 1.19 s, sys: 28 ms, total: 1.21 s
# Wall time: 1.21 s

# %%
# for i,rowlist in enumerate(newlist):
#   if len(rowlist) > 1 and i < 1000:
# #     print(i+2,rowlist)

# %%
#removing common word and len> 3
longlist = []

commonword4 = ["empty","university","create","center","centre","date","march","holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]



for i,rowlist in enumerate(newlist):
  temprow = []
  for ele in rowlist:
    ele = str(ele).lower()
    if len(ele) > 3 and ele not in commonword4 and "empty" not in ele: #ele.strip().lower() != "date" and ele.strip().lower() != "march":
      temprow.append(ele)
#     elif i < 1000:
# #       print(i+2,ele,rowlist)

  longlist.append(temprow)
 

print(len(longlist))
# Out:
# 153961

# %%
i =23546
print(i,longlist[i],valuesall[i])
# Out:
# 23546 ['los angeles'] Los Angeles, 1947

# %%
print(2500%1000)
# Out:
# 500

# %%
# %%time
#free vag subtring
vagfreelist = []

uniquelist1 = []


for i,rowlist in enumerate(longlist):
  temprow = []
  for ele1 in rowlist:
    ele1 = ele1
    flag1=0
    for token in en_nlp(str(valuesall[i])):
      if token.lower_.strip() == ele1:
        flag1 = 1
    
    counttoken = 0
    for token in en_nlp(str(ele1)):
      counttoken+=1
    if flag1 == 1 or counttoken>1 or ele1 == 'mila' or ele1 == 'chile':
      if ele1 == 'mila' and 'milan' in str(str(valuesall[i]).lower()):
        temprow.append(ele1)
      else:
        temprow.append(ele1)
    else:
      if ele1 not in uniquelist1:
        uniquelist1.append(ele1)
        print(str(i) + ") "+str(ele1) +"------>" + str(rowlist) +"-------"+ str(valuesall[i]))
  vagfreelist.append(temprow)
# Out:
# 27) illingen------>['germany', 'illingen']-------Villingen, Germany
# 39) galle------>['schaffhausen', 'galle', 'switzerland']-------Vebikus Art Gallery, Schaffhausen, Switzerland
# 161) lingen------>['germany', 'lingen']-------Reilingen, Germany
# 185) west------>['west']-------Westwood, MA, April-May 1995
# 202) bell------>['bell', 'salem']-------LuBell Farm, South Salem
# 232) kent------>['fukushima', 'japan', 'kent']-------Kentfield, CA & Fukushima Concert Hall, Japan
# 297) vite------>['vite', 'porsgrunn']-------"Det Hvite Hus", Porsgrunn, March 9-11, 1985
# 312) berlin------>['ohio', 'berlin']-------Finney Chapel, Oberlin, Ohio
# 334) green------>['rhode island', 'green', 'west']-------West Greenwich, Rhode Island, July 27, 28 & 29, 1992
# 348) mateur------>['dusseldorf', 'mateur']-------Live "Deutsches Amateur Jazz Festival 1959", Dusseldorf
# 350) halle------>['germany', 'halle', 'hamburg']-------Live "Musikhalle", Hamburg, Germany
# ...

# %%
i =23546
print(i,vagfreelist[i],valuesall[i])
# Out:
# 23546 ['los angeles'] Los Angeles, 1947

# %%
print(vagfreelist)
print(len(uniquelist1))
print(uniquelist1)

# %%
# for i in range(0,1000):
#   print(vagfreelist[i])

# %%
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0
for i,rowlist in enumerate(vagfreelist):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count5=count5+1
  if len(rowlist) ==6:
    print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)
# Out:
# 112557['russia', 'craiova', 'moscow', 'riga', 'romania', 'latvia']-------------------Concerts, Moscow, Russia; Riga, Latvia; Craiova, Romania
# count0 16604
# count1 119366
# count2 17001
# count3 878
# count4 85
# count5 26
# count6 1
# count7 0
# maxlen 6

# %%
# nocommonlist = []

# commonword4 = ["university","create","center","centre","holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]

# for i,rowlist in enumerate(vagfreelist):
#   temprow = []
#   for ele1 in rowlist:
#     if ele1 != 'university' and ele1 != 'create' and ele1 != 'center' and ele1 != 'centre':
#       temprow.append(ele1)
#   nocommonlist.append(temprow)
  
# print(len(nocommonlist))

# %%
# %%time
# #remove country
# for i,ele in enumerate(uniquelist1):
#   for ele2 in coulist:
#     ele2 = str(ele2).lower().strip()
#     if ele1 in ele2:
#       print(ele1,ele2)

# %%
# %%time
#remove country

nocoulist = []
onlycoulist = []
for i,rowlist in enumerate(vagfreelist):
  temprowno = []
  temprowonly = []
  flag2 = 0
  for ele1 in rowlist:
#     ele1 = str(ele1).lower
    flag2 = 0
    for ele2 in coulist:
      ele2 = str(ele2).lower().strip()
      if ele1 in ele2:
        flag2 = 1
        temprowonly.append(ele1)
        
    if flag2 == 0 and ele1 =='england':
      temprowonly.append(ele1)
      
    if flag2 == 0 and ele1 !='england':
      temprowno.append(ele1)
  nocoulist.append(temprowno)
  onlycoulist.append(temprowonly)
  

print(len(nocoulist))
print(len(onlycoulist))
# Out:
# 153961
# 153961
# CPU times: user 19.7 s, sys: 3 ms, total: 19.7 s
# Wall time: 19.7 s

# %%
#onlycoulist show
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0
for i,rowlist in enumerate(onlycoulist):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count5=count5+1
  if len(rowlist) ==6:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
#     print(str(i) + ")    "+str(rowlist) +"-------------------"+ valuesall[i])
    
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)

uniquecountry = []
for i,rowlist in enumerate(onlycoulist):
  for ele1 in rowlist:
    if ele1 not in uniquecountry:
      uniquecountry.append(ele1)

print(len(uniquecountry))
# Out:
# count0 139823
# count1 13756
# count2 367
# count3 14
# count4 0
# count5 1
# count6 0
# count7 0
# maxlen 5
# 122

# %%
#nocoulist show
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0
for i,rowlist in enumerate(nocoulist):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count5=count5+1
  if len(rowlist) ==6:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
#     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)
# Out:
# count0 20125
# count1 126076
# count2 7317
# count3 373
# count4 66
# count5 4
# count6 0
# count7 0
# maxlen 5

# %%
# finallist2 #keeping few city even not matched
# impnolist = [2303,2980,12213,16866,19959,23661,27217,30673,33388,41923,50037,56470,60473,74250,108843,128467,129008,129225,131468,133676,133948,137265,145275,152741,153082]
impnamelist= ['los angeles','Los Angeles', 'montreal', 'neumunster', 'gjovik', 'arhus', 'geneve', 'torshavn', 'kungalv', 'dusseldorf', 'sao paulo', 'montlucon', 'liege', 'lulea', 'pitea', 'goteborg', 'wahiawa', 'gdansk', 'nurnberg', 'alesund', 'san luis potosi', 'enkoping', 'kihei', 'gyor', 'malmo', 'levis', 'saarbrucken', 'holbaek']
finallist2 = []
uniquelist3 = []
for i,rowlist in enumerate(nocoulist):
  temprow = []
  for ele1 in rowlist:
    if len(rowlist) < 2:
       temprow.append(ele1)
    else:
      flag2 = 0
      for ele2 in subcoulist:
        ele2 = str(ele2).lower().strip()
        if ele1 in ele2:
          flag2 = 1
          temprow.append(ele1)
          break
      flag3 = 0
      if flag2 == 0:
        for ele3 in namelist:
          ele3 = str(ele3).lower().strip()
          if ele1 in ele3:
            flag3 = 1
            temprow.append(ele1)
            break
      if flag3 == 0 and flag2 ==0:
        flag4 = 0
        if ele1 in impnamelist:
          temprow.append(ele1)
          flag4 = 1
      if flag2 == 0 and flag3 ==0 and flag4 ==0:
        if ele1 not in uniquelist3 and ("NA" not in ele1):
          uniquelist3.append(ele1)
          print(str(i) + ")    "+ str(ele1) +"<====="+ str(rowlist) +"------------------->"+ str(valuesall[i]))
  
  finallist2.append(temprow)
print(len(finallist2))
# Out:
# 3836)    vanlose<=====['copenhagen', 'vanlose']------------------->Vanlose Bio, Copenhagen
# 3942)    panorama<=====['kortrijk', 'panorama']------------------->Jazz Panorama, Stadsschouwburg, Kortrijk
# 9161)    claudio<=====['montreal', 'claudio']------------------->Live "Claudio's", Montreal, December 16 & 17, 1991
# 29934)    perez<=====['new orleans', 'perez']------------------->Live "Perez Club", New Orleans, LA
# 37316)    creteil<=====['paris', 'creteil']------------------->Creteil, Paris
# 42768)    vastmanland<=====['vastmanland', 'uppsala']------------------->Live "Vastmanland-Dala Nation", Uppsala, Sweden
# 64008)    chatelet<=====['paris', 'chatelet']------------------->"Theatre du Chatelet", Paris, France
# 65056)    hurth<=====['aachen', 'hurth']------------------->Live, "Burgerhaus Hurth", Aachen, Germany
# 107709)    heliopolis<=====['heliopolis', 'cairo']------------------->Heliopolis, Cairo, Egypt
# ...

# %%
# print(impnamelist)

# %%
print(len(finallist2))
print(len(uniquelist3))
# Out:
# 153961
# 14

# %%
print(finallist2[140810])
# Out:
# ['lisbon']

# %%
finallist3 = [] 

for i,rowlist in enumerate(finallist2):
  temprow = []
  for ele1 in rowlist:
    if "na-" not in ele1:
      temprow.append(ele1)
#     else:
#       print(str(i) + ")    "+str(rowlist) +"-------------------"+ str(valuesall[i]))
  finallist3.append(temprow)
print(len(finallist3))
# Out:
# 153961

# %%
#finallist2 show
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0


# commonword4 = ["holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]

# uniquerow4 = []
for i,rowlist in enumerate(finallist3):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + ")    "+str(rowlist) +"-------------------"+ str(valuesall[i]))
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count5=count5+1
  if len(rowlist) ==6:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
#     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)

# print(len(uniquerow4))
# Out:
# count0 22757
# count1 123471
# count2 7290
# count3 373
# count4 66
# count5 4
# count6 0
# count7 0
# maxlen 5

# %%
# #finallist2 show
# count0 = 0
# count1 = 0
# count2 = 0
# count3 = 0
# count4 = 0
# count5 = 0
# count6 = 0
# count7 = 0
# maxlen = 0


# commonword4 = ["holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]

# uniquerow4 = []
# for i,rowlist in enumerate(finallist2):
#   if len(rowlist) ==0:
# #     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
#     count0=count0+1
#   if len(rowlist) ==1:
# #     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
#     count1=count1+1
#   if len(rowlist) ==2 and "&" not in str(valuesall[i]) and " and" not in str(valuesall[i]):
#     flag1 = 0
#     for ele1 in rowlist:
#       if ele1 in commonword4:
#         flag1 = 1
#     if flag1 == 0:
#       count2=count2+1
#       if rowlist not in uniquerow4:
#         uniquerow4.append(rowlist)
#         print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    
#   if len(rowlist) ==3:
# #     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
#     count3=count3+1
#   if len(rowlist) ==4:
# #     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
#     count4=count4+1
#   if len(rowlist) ==5:
# #     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
#     count5=count5+1
#   if len(rowlist) ==6:
# #     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
#     count6=count6+1
#   if len(rowlist) ==7:
# #     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
#     count7=count7+1
#   if len(rowlist) > maxlen:
#     maxlen = len(rowlist)
# #     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
# print("count0",count0)
# print("count1",count1)
# print("count2",count2)
# print("count3",count3)
# print("count4",count4)
# print("count5",count5)
# print("count6",count6)
# print("count7",count7)
# print("maxlen", maxlen)

# print(len(uniquerow4))

# %%
# 89601 empty
#80136 sub + country
#81266 in city
#75933

# %%
# count1 = 0
# count2 = 0

# uniquerowand = []
# uniquerowno = []

# for i,rowlist in enumerate(finallist3):
#   if len(rowlist) >=2:
#     if "&" in str(valuesall[i]) or " and" in str(valuesall[i]):
#       count1+=1
#       if rowlist not in uniquerowand:
#         uniquerowand.append(rowlist)
#         print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
#     else:
#       count2+=1
#       if rowlist not in uniquerowno:
#         uniquerowno.append(rowlist)
# #         print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))

# print(len(uniquerowand))
# print(len(uniquerowno))

# %%
# finallist4 = []

# # count1 = 0
# # count2 = 0

# uniquerowand2 = []
# uniquerowno2 = []

# for i,rowlist in enumerate(finallist3):
#   temprow = []
#   if len(rowlist) >=2:
#     for ele1 in rowlist:
#       flag1 = 0
#       if ele1 in impnamelist:
#         flag1 = 1
#         temprow.append(ele1)
#       if flag1 ==0:
#         flag2 = 0
#         for ele2 in subcoulist:
#           ele2 = str(ele2).lower().strip()
#           if ele1 in ele2:
#             flag2 = 1
#             temprow.append(ele1)
#             break
#         if flag2 ==0:
# #           if "&" in str(valuesall[i]) or " and" in str(valuesall[i]):
# #             if ele1 not in uniquerowand2:
# #               uniquerowand2.append(ele1)
# #               print(str(i) + ")    " + str(ele1) + str(rowlist) +"-------------------"+ str(valuesall[i]))
# #           else:
#           if ele1 not in uniquerowno2:
#             uniquerowno2.append(ele1)
#             print(str(i) + ")    "  + str(ele1) + "    "+ str(rowlist) +"-------------------"+ str(valuesall[i]))
        
    
    
# print(len(uniquerowand2))
# print(len(uniquerowno2))

# # "san francisco","falun","hollywood",melbourne,st. Louis,arnhem,
# Out:
# 47)    laporte    ['colorado', 'laporte']-------------------"Eye in the Sky", Laporte, Colorado, May 24 & 25, 1996
# 51)    evanston    ['illinois', 'evanston']-------------------Evanston, Illinois, c. 1983
# 120)    denver    ['colorado', 'denver']-------------------Denver, Colorado
# 132)    st. louis    ['st. louis', 'missouri']-------------------St. Louis, Missouri
# 204)    waterloo    ['iowa', 'waterloo']-------------------Waterloo, Iowa
# 320)    minneapolis    ['minnesota', 'minneapolis']-------------------Minneapolis, Minnesota
# 331)    des moines    ['iowa', 'des moines']-------------------Des Moines, Iowa
# 337)    arnhem    ['luxor', 'arnhem']-------------------Luxor Theatre, Arnhem
# 456)    miami    ['florida', 'miami']-------------------Miami, Florida
# 458)    glenview    ['glenview', 'illinois']-------------------Glenview, Illinois
# 471)    hollywood    ['los angeles', 'hollywood']-------------------Los Angeles & Hollywood, CA
# ...

# %%
#lastfinallist
uniquerowand3 = []
uniquerowno3 = []


lastfinallist = []


hardsortlist = ['sudbury', 'pawtucket', 'bloomington', 'louisville', 'louisville', 'versailles', 'lexington', 'hopkinsville','cambridge', 'somerville', 'reading','montclair', 'long branch','dallas', 'reading','sparks', 'reno','richmond', 'menlo park','catania','columbus', 'phoenix', 'bloomfield', 'east point', 'dearborn', 'lansing','boulder', 'greeley', 'nijmegen','avignon', 'paramus','tallinn', 'osaka', 'san antonio','los altos', 'redwood city','helsinki', 'brookline','yokohama','phoenix', 'tempe','boulder','louisville', 'greensboro','meyrin', 'malnate','welwyn garden city', 'northampton','winnipeg','westport','dresden', 'erfurt','nashville', 'alhambra','weiden','southsea','torrance', 'santa barbara', 'nassau','tarragona', 'palm springs','dallas', 'irving','colinas','carmel', 'monterey', 'stamford','dearborn', 'hudson', 'wethersfield', 'birmingham','toulouse', 'blagnac', 'stockport', 'wigan','bucharest', 'keswick', 'dartmouth','pasadena','hastings','marseille', 'yerres','arlington', 'mainz','costa mesa', 'tustin','ludwigsburg', 'heidelberg','caldwell','laguna','yokohama', 'osaka','taunton', 'plymouth', 'appleton', 'long branch','santa barbara','orlando', 'tampa','miami', 'havana','belmont', 'portland','carlisle', 'danvers','charleston','whitley bay', 'kobe', 'celle','acireale','derby','san diego','concord','kansas city','jackson','glen cove', 'mineola', 'bournemouth', 'rockford', 'sheridan','kansas city','san diego','baltimore','wiesbaden', 'hannover','the hague','pozzallo', 'siracusa','sherman oaks', 'strasbourg','anderson', 'indianapolis','carlisle', 'stoughton', 'durham','johannesburg', 'oakland','willoughby','palatine','new bedford','atlanta', 'nagoya', 'dendermonde','schwabach','pescara','santa monica','newport', 'milwaukee','houston','cologne', 'stuttgart','Laguna Beach','syracuse','coventry', 'fremont', 'cannes','canoga park', 'calabasas','innsbruck', 'hanover','leeds','norwich', 'bedford', 'freiburg', 'reims','kearny', 'minneapolis','naples','franklin', 'brandon','newark','rotterdam', 'dordrecht','bussum','bonn','buffalo', 'boston', 'atlantic city','colorado springs','scheveningen', 'villejuif','bologna', 'pistoia','udine','thornton','bratislava', 'essex', 'baarn','seattle', 'mountlake terrace','rotterdam', 'amsterdam','melbourne', 'sydney','hoboken','beverly', 'wellesley','pittsburgh','fort lauderdale','amersfoort','brighton','Yarmouth', 'memphis','bordeaux', 'frankfurt','brooklyn', 'paterson','alkmaar', 'bracknell','saratoga','amherst','west hollywood', 'burbank','sacramento', 'san jose', 'englewood', 'barnet','las vegas','copenhagen','neu-ulm','north hollywood','iserlohn', 'dortmund', 'culver city','venice','munich','claremont','tortona', 'dublin','cincinnati', 'detroit','albany','wilton', 'montreux','westbury','paris', 'burbank', 'vancouver','seattle','rochester', 'west orange','denver','cleveland','new orleans','st. louis','rome', 'montreux','berkeley','chicago','brno', 'prague','suisun','falun','san francisco','hollywood', 'toronto','philadelphia','burbank','paris','london', 'silver spring','surrey','glendale', 'san rafael','westminster']
hardsortlist = np.unique(hardsortlist)
print("hardsortlist:",len(hardsortlist))
for i,rowlist in enumerate(finallist3):
  temprow = []
  if len(rowlist) > 1:
    flag3 = 0
    for ele1 in rowlist:
      flag1 = 0
      if ele1 in impnamelist:
        flag1 = 1
        flag3 = 1
        temprow.append(ele1)
        
      flag2 = 0
      if flag1 ==0:
        for ele2 in subcoulist:
          ele2 = str(ele2).lower().strip()
          if ele1 in ele2:
            flag2 = 1
            flag3 = 1
            temprow.append(ele1)
            break
            
      flag4 = 0
      if flag1 ==0:
        if ele1 in hardsortlist:
          flag4 = 1
          flag3 = 1
          temprow.append(ele1)
    if flag3 ==0:
#       flag5=0
#       for ele1 in rowlist:
#         if ele1 not in uniquerowno3:
#           uniquerowno3.append(ele1)
#           flag5=1
#       if flag5 == 1:    
      print(str(i) + ")    "+ str(rowlist) +"-------------------"+ str(valuesall[i]))        
  else:
    temprow = rowlist
    
    
  lastfinallist.append(temprow)  
# print(len(uniquerowand3))
# print(len(uniquerowno3))
print(len(lastfinallist))

# hardsortlist = ['innsbruck', 'hanover','leeds','norwich', 'bedford', 'freiburg', 'reims','kearny', 'minneapolis','naples','franklin', 'brandon','newark','rotterdam', 'dordrecht','bussum','bonn','buffalo', 'boston', 'atlantic city','colorado springs','scheveningen', 'villejuif','bologna', 'pistoia','udine','thornton','bratislava', 'essex', 'baarn','seattle', 'mountlake terrace','rotterdam', 'amsterdam','melbourne', 'sydney','hoboken','beverly', 'wellesley','pittsburgh','fort lauderdale','amersfoort','brighton','Yarmouth', 'memphis','bordeaux', 'frankfurt','brooklyn', 'paterson','alkmaar', 'bracknell','saratoga','amherst','west hollywood', 'burbank','sacramento', 'san jose', 'englewood', 'barnet','las vegas','copenhagen','neu-ulm','north hollywood','iserlohn', 'dortmund', 'culver city','venice','munich','claremont','tortona', 'dublin','cincinnati', 'detroit','albany','wilton', 'montreux','westbury','paris', 'burbank', 'vancouver','seattle','rochester', 'west orange','denver','cleveland','new orleans','st. louis','rome', 'montreux','berkeley','chicago','brno', 'prague','suisun','falun','san francisco','hollywood', 'toronto','philadelphia','burbank','paris','london', 'silver spring','surrey','glendale', 'san rafael','westminster']





# 'johannesburg', 'oakland','willoughby','palatine','new bedford','atlanta', 'nagoya', 'dendermonde','schwabach','pescara','santa monica','newport', 'milwaukee','houston','cologne', 'stuttgart'



# 'orlando', 'tampa','miami', 'havana','belmont', 'portland','carlisle', 'danvers','charleston','whitley bay', 'kobe', 'celle','acireale','derby','san diego','concord','kansas city','jackson','glen cove', 'mineola', 'bournemouth', 'rockford', 'sheridan','kansas city','san diego','baltimore','wiesbaden', 'hannover','the hague','pozzallo', 'siracusa','sherman oaks', 'strasbourg','anderson', 'indianapolis','carlisle', 'stoughton',, 'durham'

# 'sudbury', 'pawtucket', 'bloomington', 'louisville', 'louisville', 'versailles', 'lexington', 'hopkinsville','cambridge', 'somerville', 'reading','montclair', 'long branch','dallas', 'reading','sparks', 'reno','richmond', 'menlo park','catania','columbus', 'phoenix', 'bloomfield', 'east point', 'dearborn', 'lansing','boulder', 'greeley', 'nijmegen','avignon', 'paramus','tallinn', 'osaka', 'san antonio','los altos', 'redwood city','helsinki', 'brookline','yokohama','phoenix', 'tempe','boulder','louisville', 'greensboro','meyrin', 'malnate','welwyn garden city', 'northampton','winnipeg','westport','dresden', 'erfurt','nashville', 'alhambra','weiden','southsea','torrance', 'santa barbara', 'nassau','tarragona', 'palm springs','dallas', 'irving','colinas','carmel', 'monterey', 'stamford','dearborn', 'hudson', 'wethersfield', 'birmingham','toulouse', 'blagnac', 'stockport', 'wigan','bucharest', 'keswick', 'dartmouth','pasadena','hastings','marseille', 'yerres','arlington', 'mainz','costa mesa', 'tustin','ludwigsburg', 'heidelberg','caldwell','laguna','yokohama', 'osaka','taunton', 'plymouth', 'appleton', 'long branch','santa barbara',
# Out:
# hardsortlist: 245
# 15597)    ['springs', 'antioch']-------------------Live, "Antioch Theatre, Antioch College", Yellow Springs, OH
# 25540)    ['wright', 'yarmouth']-------------------Yarmouth, Isle of Wright
# 134232)    ['downey', 'morton']-------------------radio broadcast, "Morton Downey Show", Spring 1951
# 139514)    ['springs', 'sulphur']-------------------Spotlight bands broadcast #524, White Sulphur Springs, W.VA
# 153961

# %%
#lastfinallist show
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0


# commonword4 = ["holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]

# uniquerow4 = []
for i,rowlist in enumerate(lastfinallist):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + ")    "+str(rowlist) +"-------------------"+ str(valuesall[i]))
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count5=count5+1
  if len(rowlist) ==6:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
#     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)

# print(len(uniquerow4))
# Out:
# count0 22761
# count1 126697
# count2 4253
# count3 209
# count4 40
# count5 1
# count6 0
# count7 0
# maxlen 5

# %%
filename = "lastfinallist.csv"
my_df = pd.DataFrame(lastfinallist)
my_df.to_csv(filename)

from google.colab import files
downloaded = files.download(filename)

# %%
# filename = "hardsortlist.csv"
# my_df = pd.DataFrame(hardsortlist)
# my_df.to_csv(filename)

# from google.colab import files
# downloaded = files.download(filename)

# %%
# filename = "finallist3.csv"
# my_df = pd.DataFrame(finallist3)
# my_df.to_csv(filename)

# from google.colab import files
# downloaded = files.download(filename)

# %%
# filename = "finallist2.csv"
# my_df = pd.DataFrame(finallist2)
# my_df.to_csv(filename)

# from google.colab import files
# downloaded = files.download(filename)

# %%
# filename = "longlist.csv"
# my_df = pd.DataFrame(longlist)
# my_df.to_csv(filename)

# from google.colab import files
# downloaded = files.download(filename)

# %%
lastfinallist2 = lastfinallist

for i,rowlist in enumerate(lastfinallist2):
  for j,ele1 in enumerate(rowlist):
    for k,ele2 in enumerate(namelist):
      ele2 = str(ele2).lower().strip()
      if ele1 in ele2:
        lastfinallist2[i][j] = str(subcoulist[k]).lower().strip()
        break
  lastfinallist2[i] = np.unique(lastfinallist2[i])
   
print(len(lastfinallist2))
# Out:
# 153961

# %%
#lastfinallist show
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
maxlen = 0


# commonword4 = ["holidays","holiday","same","summit","sunset","nord","orange","liberal","metro","prospect","elizabeth","papa","golden","mobile","sale","than","longview","best","state college","college"]

# uniquerow4 = []
for i,rowlist in enumerate(lastfinallist2):
  if len(rowlist) ==0:
#     print(str(i) + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count0=count0+1
  if len(rowlist) ==1:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count1=count1+1
  if len(rowlist) ==2:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count2=count2+1
  if len(rowlist) ==3:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count3=count3+1
  if len(rowlist) ==4:
#     print(str(i) + ")    "+str(rowlist) +"-------------------"+ str(valuesall[i]))
    count4=count4+1
  if len(rowlist) ==5:
#     print(str(i) + ")    " + str(rowlist) +"-------------------"+ str(valuesall[i]))
    count5=count5+1
  if len(rowlist) ==6:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count6=count6+1
  if len(rowlist) ==7:
#     print(str(i) + str(rowlist) +"-------------------"+ valuesall[i])
    count7=count7+1
  if len(rowlist) > maxlen:
    maxlen = len(rowlist)
#     print(str(i) + ")    " + str(maxlen)+"------"+str(rowlist) +"-------------------"+ str(valuesall[i]))
print("count0",count0)
print("count1",count1)
print("count2",count2)
print("count3",count3)
print("count4",count4)
print("count5",count5)
print("count6",count6)
print("count7",count7)
print("maxlen", maxlen)

# print(len(uniquerow4))
# Out:
# count0 22761
# count1 126785
# count2 4171
# count3 204
# count4 40
# count5 0
# count6 0
# count7 0
# maxlen 4

# %%
filename = "lastfinallist2.csv"
my_df = pd.DataFrame(lastfinallist2)
my_df.to_csv(filename)

from google.colab import files
downloaded = files.download(filename)

# %%
# count0 22761
# count1 126697
# count2 4253
# count3 209
# count4 40
# count5 1



# count0 22761
# count1 126785
# count2 4171
# count3 204
# count4 40

# %%
df = pd.DataFrame({
    'col1' : ['A', 'A', 'B', np.nan, 'D', 'C'],
    'col2' : [2, 1, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, 3]})

# %%
print(df)
# Out:
#   col1  col2  col3
# 0    A     2     0
# 1    A     1     1
# 2    B     9     9
# 3  NaN     8     4
# 4    D     7     2
# 5    C     4     3

# %%
print(df.columns)
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df2 = df.sort_values(by=['col1'])

# %%
print(df2)
# Out:
#   col1  col2  col3
# 0    A     2     0
# 1    A     1     1
# 2    B     9     9
# 5    C     4     3
# 4    D     7     2
# 3  NaN     8     4
